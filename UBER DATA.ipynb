# %%
                                       # import libraries #

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.style.use('ggplot')
import calendar
import datetime
import warnings
warnings.filterwarnings('ignore'),
# Out:
# (None,)

# %%
                                    # Read the data #

# %%
df1 = pd.read_csv('Uber Data')
df1.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
                                    # define the shape #

# %%
df1.shape
# Out:
# (1156, 7)

# %%
                                 # define the describe #

# %%
df1.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
                                   # define info #

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
                                 # define type #

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
                                 # finding the null values #

# %%
df1.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
                                 # drop the null values #

# %%
df1.dropna(inplace = True)

# %%
                            # lets again check the null values #

# %%
df1.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %%
                             # data visual for null values #

# %%
sns.heatmap(df1.isnull(), yticklabels = False)
# Out:
# <AxesSubplot: >

# %%
df1
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
                                         # Transforimg the data #
                 # find the data in terms of hours, number of days, and months per year #

# %%
df1['START_DATE*'] = pd.to_datetime(df1['START_DATE*'], format="%m/%d/%Y %H:%M" )
df1['END_DATE*'] = pd.to_datetime(df1['END_DATE*'], format="%m/%d/%Y %H:%M" )

# %%
hour = []
day = []
dayofweek = []
month = []
weekday = []
for x in df1['START_DATE*']:
    hour.append(x.hour)
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
df1['HOUR'] = hour
df1['DAY'] = day
df1['DAY_OF_WEEK'] = dayofweek
df1['MONTH'] = month
df1['WEEKDAY'] = weekday

# %%
df1.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY
# 0     Friday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday
# 5  Wednesday

# %%
                                        # find the travelling time #

# %%
time = []
df1['TRAVELLING_TIME'] = df1['END_DATE*'] - df1['START_DATE*']
for i in df1['TRAVELLING_TIME']:
    time.append(i.seconds/60)
df1['TRAVELLING_TIME'] = time
df1.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY  TRAVELLING_TIME
# 0     Friday              6.0
# 2   Saturday             13.0
# ...

# %%
                                 # calculating the average speed of time #

# %%
df1['TRAVELLING_TIME'] = df1['TRAVELLING_TIME']/60
df1['SPEED'] = df1['MILES*']/df1['TRAVELLING_TIME']
df1.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY  TRAVELLING_TIME      SPEED
# 0     Friday         0.100000  51.000000
# ...

# %%
                           # visualizing the data in histogram

# %%
df1['MILES*'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
                                    # visualize the data in strip plot
                          # what is the highest month of travelling time# - "march"

# %%
plt.figure(figsize=(8,5))
sns.stripplot(y = 'TRAVELLING_TIME',x = 'MONTH', data = df1,color = 'orange',)
plt.xlabel('MONTH')
plt.ylabel('TRAVELLING_TIME')
# Out:
# Text(0, 0.5, 'TRAVELLING_TIME')

# %%
df1.WEEKDAY=df1.WEEKDAY.map({'Sunday':1, 'Monday':2, 'Tuesday':3, 'Wednesday':4, 'Thursday':5, 'Friday':6, 'Saturday':7})
df1['WEEKDAY'].value_counts()
# Out:
# 6    125
# 3     94
# 5     92
# 1     87
# 2     87
# 4     85
# 7     83
# Name: WEEKDAY, dtype: int64

# %%
df1
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# 5    2016-01-06 17:15:00 2016-01-06 17:19:00  Business   West Palm Beach
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  \
# ...

# %%
                                    # visualize the data in strip plot
                        # most of the travelling days are  friday, saturday, and sunday #

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y = 'TRAVELLING_TIME',x = 'WEEKDAY', data = df1,color = 'purple',)
plt.xlabel('WEEKDAY')
plt.ylabel('TRAVELLING_TIME')
# Out:
# Text(0, 0.5, 'TRAVELLING_TIME')
